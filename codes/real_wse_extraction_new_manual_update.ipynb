# %% [markdown]
# # Script for web scrapping cwc real time data
# ### import libraries

# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd
import datetime
from datetime import date
from datetime import timedelta
import matplotlib.pyplot as plt
import openpyxl
from openpyxl.utils.dataframe import dataframe_to_rows
import os

# %% [markdown]
# ### date range and html json responses

# %% [markdown]
# ###### monsoon data retrieval will take time as it will extract all station hourly data

# %%
# sdate1=d2 
# edate1=d1
sdate1="2023-10-12"    #yyyy-mm-dd
edate1="2023-10-26"    #yyyy-mm-dd # may(5) 31  sep(9) 30


url1=f"""https://ffs.india-water.gov.in/iam/api/new-entry-data/specification/sorted?sort-criteria=%7B%22sortOrderDtos%22:%5B%7B%22sortDirection%22:%22ASC%22,%22field%22:%22id.dataTime%22%7D%5D%7D&specification=%7B%22where%22:%7B%22where%22:%7B%22expression%22:%7B%22valueIsRelationField%22:false,%22fieldName%22:%22id.datatypeCode%22,%22operator%22:%22eq%22,%22value%22:%22HHS%22%7D%7D,%22and%22:%7B%22expression%22:%7B%22valueIsRelationField%22:false,%22fieldName%22:%22dataValue%22,%22operator%22:%22null%22,%22value%22:%22false%22%7D%7D%7D,%22and%22:%7B%22expression%22:%7B%22valueIsRelationField%22:false,%22fieldName%22:%22id.dataTime%22,%22operator%22:%22btn%22,%22value%22:%22{sdate1}T00:00:00.250,{edate1}T23:59:59.250%22%7D%7D%7D"""

md1=None
session1=requests.session()
# data1=session1.get(url1,timeout=1000)
# soup1=BeautifulSoup(data1.content, 'html.parser')

# try:
#     md1=json.loads(soup1.get_text())
# except:
#     md1=json.loads(soup1.get_text())
    
try:
    data1 = session1.get(url1, timeout=1000)
    soup1 = BeautifulSoup(data1.content, 'html.parser')
    md1 = json.loads(soup1.get_text())
except requests.exceptions.ConnectionError as e:
    print(f"ConnectionError: {e}")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
# md1

# %%
# md1

# %% [markdown]
# ### updating data in database
# ##### here yesterdays data will be added to existing retrived data base

# %%
new=0 # this is just for checking number of new updates
old=0 # this is just to count not updated data
# df_code=pd.read_excel('name-code.xlsx',index_col=0)
df_code=pd.read_excel('F:\\phd_work\\cwc_real_time_data\\updated_real_time\\data_files\\2020_updated\\name-code.xlsx',index_col=0)
updated_path = "F:\\phd_work\\cwc_real_time_data\\updated_real_time\\data_files\\2020_updated\\data"
for name_x in df_code['name']:
    print(name_x)
    df1=df_code[df_code['name']==name_x] # remove this line if want to download all data
    dic=df1.T.to_dict()
    fl=[]


    for j in md1[:]:
        try:

            ml=[j['id']['stationCode'],datetime.datetime.fromisoformat(j['id']['dataTime']),dic[j['id']['stationCode']]['name'],j['dataValue']]
            fl.append(ml)
        except:
            pass

    try:
        excel_file=updated_path+'\\'+name_x+'2020_to2023_10_11.xlsx'
        excel_file_new=updated_path+'\\'+name_x+'2020_to2023_10_26.xlsx'
        fl=sorted(fl)   
        df=pd.DataFrame(fl)
        df.columns=['code','time','name','WSE']
#         df=df.loc[fl_size:] #round(len(fl)/2)-1 = 23 after monsoon we will not get 23 data so here we have to update
#         df=df.loc[fl_size_half:] #round(len(fl)/2)-1 = 23 after monsoon we will not get 23 data so here we have to update
#         df=df.loc[47:]

    #         df.to_excel(file_path_exp+name_x+'2023_june_July.xlsx') # change file name here
        # opening existing excel and appending updated data 
        sheet_name = 'Sheet1'
        workbook = openpyxl.load_workbook(excel_file)
        sheet = workbook[sheet_name]

        # Determine the starting row for appending
        start_row = sheet.max_row + 1

        # Append new data to the sheet
        last_index = sheet.max_row - 1  # Subtract 1 to account for 0-based indexing
#         df.index = range(last_index + 1, last_index + 1 + len(df))  # Adjust the index
        df.index = range(last_index, last_index + len(df))  # Adjust the index
        # Append new data to the sheet
        for row in dataframe_to_rows(df, index=True, header=False):
            sheet.append(row)

        # Save the changes
        workbook.save(excel_file)
        workbook.close()
        workbook=None
        workbook
        os.rename(excel_file, excel_file_new)
        new=new+1
        print('updated file count:::==>>> '+str(new)+' <<< updated path >>>>>'+excel_file_new)


    except:
        print('file not updated or not found')
# Out:
# Parwan pick-up Weir
# file not updated or not found
# Kalisindh Dam
# file not updated or not found
# Mirawadi
# file not updated or not found
# Yadgir
# updated file count:::==>>> 1 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Yadgir2020_to2023_10_26.xlsx
# Wadakbal
# file not updated or not found
# Ithai_WLR
# file not updated or not found
# Panchana Dam
# file not updated or not found
# Targaon
# updated file count:::==>>> 2 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Targaon2020_to2023_10_26.xlsx
# Kursela
# updated file count:::==>>> 3 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kursela2020_to2023_10_26.xlsx
# VAPI
# updated file count:::==>>> 4 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\VAPI2020_to2023_10_26.xlsx
# Yingkiong
# updated file count:::==>>> 5 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Yingkiong 2020_to2023_10_26.xlsx
# RAMESHWAR
# updated file count:::==>>> 6 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\RAMESHWAR2020_to2023_10_26.xlsx
# Jauljibi
# file not updated or not found
# Bamni (Ballarsha)
# updated file count:::==>>> 7 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Bamni (Ballarsha)2020_to2023_10_26.xlsx
# Singur Reservoir
# file not updated or not found
# Abu Road
# updated file count:::==>>> 8 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Abu Road2020_to2023_10_26.xlsx
# PURNAGIRI
# file not updated or not found
# Ayodhya
# updated file count:::==>>> 9 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Ayodhya 2020_to2023_10_26.xlsx
# Madkote
# file not updated or not found
# Irilbung_WLR
# file not updated or not found
# Bhagalpur
# file not updated or not found
# RUPALIGAD
# updated file count:::==>>> 10 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\RUPALIGAD2020_to2023_10_26.xlsx
# Gudha Dam
# file not updated or not found
# Moradabad
# file not updated or not found
# Dabri
# updated file count:::==>>> 11 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Dabri2020_to2023_10_26.xlsx
# Manderial
# updated file count:::==>>> 12 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Manderial2020_to2023_10_26.xlsx
# Getalsud Reservoir
# file not updated or not found
# SARANGKHEDA
# file not updated or not found
# Malkhed
# updated file count:::==>>> 13 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Malkhed2020_to2023_10_26.xlsx
# Tilaiya Reservoir
# updated file count:::==>>> 14 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Tilaiya Reservoir2020_to2023_10_26.xlsx
# Dharoi Dam
# updated file count:::==>>> 15 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Dharoi Dam2020_to2023_10_26.xlsx
# NT Road Crossing Jia-Bharali
# updated file count:::==>>> 16 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\NT Road Crossing Jia-Bharali2020_to2023_10_26.xlsx
# BAMRUL
# updated file count:::==>>> 17 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\BAMRUL2020_to2023_10_26.xlsx
# Gaura
# updated file count:::==>>> 18 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Gaura2020_to2023_10_26.xlsx
# KATRAGADDA
# file not updated or not found
# Harshil
# updated file count:::==>>> 19 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Harshil2020_to2023_10_26.xlsx
# NATHPA
# updated file count:::==>>> 20 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\NATHPA2020_to2023_10_26.xlsx
# PANCHARATNA
# updated file count:::==>>> 21 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\PANCHARATNA2020_to2023_10_26.xlsx
# Ghodopipli
# updated file count:::==>>> 22 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Ghodopipli2020_to2023_10_26.xlsx
# ETAWAH
# updated file count:::==>>> 23 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\ETAWAH2020_to2023_10_26.xlsx
# Mohammad Ganj
# updated file count:::==>>> 24 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Mohammad Ganj2020_to2023_10_26.xlsx
# Sonapur
# updated file count:::==>>> 25 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sonapur2020_to2023_10_26.xlsx
# Hipparagi Barrage
# updated file count:::==>>> 26 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Hipparagi Barrage2020_to2023_10_26.xlsx
# Kakrahi
# file not updated or not found
# Hathnikund Barrage
# updated file count:::==>>> 27 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Hathnikund Barrage2020_to2023_10_26.xlsx
# PIMPRI
# updated file count:::==>>> 28 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\PIMPRI2020_to2023_10_26.xlsx
# PVNRao Kantanapally Project
# file not updated or not found
# Chepan
# updated file count:::==>>> 29 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Chepan2020_to2023_10_26.xlsx
# Jamshedpur
# updated file count:::==>>> 30 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Jamshedpur2020_to2023_10_26.xlsx
# Paonta
# updated file count:::==>>> 31 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Paonta2020_to2023_10_26.xlsx
# NAWTHA
# updated file count:::==>>> 32 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\NAWTHA2020_to2023_10_26.xlsx
# Kasmara
# updated file count:::==>>> 33 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kasmara2020_to2023_10_26.xlsx
# Mount Abu
# file not updated or not found
# Neamatighat
# updated file count:::==>>> 34 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Neamatighat2020_to2023_10_26.xlsx
# Sapawada
# file not updated or not found
# Ganeshpura
# updated file count:::==>>> 35 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Ganeshpura2020_to2023_10_26.xlsx
# Isapur Reservoir
# updated file count:::==>>> 36 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Isapur Reservoir2020_to2023_10_26.xlsx
# Garhmukteshwar
# file not updated or not found
# Matijuri
# updated file count:::==>>> 37 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Matijuri2020_to2023_10_26.xlsx
# DHUPESHWAR
# updated file count:::==>>> 38 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\DHUPESHWAR2020_to2023_10_26.xlsx
# Panposh
# updated file count:::==>>> 39 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Panposh2020_to2023_10_26.xlsx
# TALASWADA
# updated file count:::==>>> 40 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\TALASWADA2020_to2023_10_26.xlsx
# WANKHED
# updated file count:::==>>> 41 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\WANKHED2020_to2023_10_26.xlsx
# Amarpur
# updated file count:::==>>> 42 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Amarpur2020_to2023_10_26.xlsx
# Mandleshwar
# updated file count:::==>>> 43 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Mandleshwar2020_to2023_10_26.xlsx
# Vautha
# updated file count:::==>>> 44 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Vautha2020_to2023_10_26.xlsx
# Handia
# updated file count:::==>>> 45 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Handia2020_to2023_10_26.xlsx
# Mahulpali
# file not updated or not found
# MOORANG
# updated file count:::==>>> 46 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\MOORANG2020_to2023_10_26.xlsx
# Muri
# updated file count:::==>>> 47 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Muri2020_to2023_10_26.xlsx
# Seohara
# updated file count:::==>>> 48 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Seohara2020_to2023_10_26.xlsx
# Bamni
# updated file count:::==>>> 49 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Bamni2020_to2023_10_26.xlsx
# ID Lohaghat
# file not updated or not found
# Jalaput dam (Machkund)
# updated file count:::==>>> 50 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Jalaput dam (Machkund)2020_to2023_10_26.xlsx
# Tenughat Reservoir
# updated file count:::==>>> 51 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Tenughat Reservoir2020_to2023_10_26.xlsx
# Kesinga
# updated file count:::==>>> 52 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kesinga2020_to2023_10_26.xlsx
# Bisalpur Reservoir
# file not updated or not found
# Bhandara
# updated file count:::==>>> 53 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Bhandara2020_to2023_10_26.xlsx
# MALLI MADUGU.
# file not updated or not found
# AGRA (J.B.)
# updated file count:::==>>> 54 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\AGRA (J.B.)2020_to2023_10_26.xlsx
# MUSIRI
# updated file count:::==>>> 55 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\MUSIRI2020_to2023_10_26.xlsx
# RIHAND DAM
# updated file count:::==>>> 56 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\RIHAND DAM2020_to2023_10_26.xlsx
# Mathani Road Bridge
# file not updated or not found
# Dhengraghat
# updated file count:::==>>> 57 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Dhengraghat2020_to2023_10_26.xlsx
# Phulgaon
# updated file count:::==>>> 58 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Phulgaon2020_to2023_10_26.xlsx
# Turtipar
# updated file count:::==>>> 59 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Turtipar2020_to2023_10_26.xlsx
# Prakasam Barrage
# updated file count:::==>>> 60 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Prakasam Barrage2020_to2023_10_26.xlsx
# Passighat
# updated file count:::==>>> 61 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Passighat2020_to2023_10_26.xlsx
# Banbasa Barrage
# file not updated or not found
# Chupkoli
# updated file count:::==>>> 62 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Chupkoli2020_to2023_10_26.xlsx
# Mirzapur
# updated file count:::==>>> 63 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Mirzapur2020_to2023_10_26.xlsx
# Tungabhadra Dam
# updated file count:::==>>> 64 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Tungabhadra Dam2020_to2023_10_26.xlsx
# Kantamal
# updated file count:::==>>> 65 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kantamal2020_to2023_10_26.xlsx
# Narayanapura Reservoir
# updated file count:::==>>> 66 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Narayanapura Reservoir2020_to2023_10_26.xlsx
# Jhanjharpur
# updated file count:::==>>> 67 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Jhanjharpur2020_to2023_10_26.xlsx
# Mawi
# updated file count:::==>>> 68 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Mawi 2020_to2023_10_26.xlsx
# SUNDAR DAM
# file not updated or not found
# Kashinagar
# updated file count:::==>>> 69 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kashinagar2020_to2023_10_26.xlsx
# RAJGHAT DAM
# file not updated or not found
# Nanded
# updated file count:::==>>> 70 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Nanded2020_to2023_10_26.xlsx
# Kokrajhar
# updated file count:::==>>> 71 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kokrajhar2020_to2023_10_26.xlsx
# Sikandarpur (Muzzafarpur)
# updated file count:::==>>> 72 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sikandarpur (Muzzafarpur)2020_to2023_10_26.xlsx
# Dummagudem
# updated file count:::==>>> 73 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Dummagudem2020_to2023_10_26.xlsx
# GOPALKHEDA
# updated file count:::==>>> 74 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\GOPALKHEDA2020_to2023_10_26.xlsx
# Deogaon
# updated file count:::==>>> 75 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Deogaon2020_to2023_10_26.xlsx
# Kunavaram
# updated file count:::==>>> 76 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kunavaram2020_to2023_10_26.xlsx
# Khairmal
# updated file count:::==>>> 77 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Khairmal2020_to2023_10_26.xlsx
# Golaghat
# updated file count:::==>>> 78 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Golaghat2020_to2023_10_26.xlsx
# Sathanur Dam
# updated file count:::==>>> 79 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sathanur Dam2020_to2023_10_26.xlsx
# Dumariaghat
# updated file count:::==>>> 80 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Dumariaghat2020_to2023_10_26.xlsx
# Polavaram Irrigation Project
# file not updated or not found
# Kota Barrage
# updated file count:::==>>> 81 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kota Barrage2020_to2023_10_26.xlsx
# AURAIYA
# updated file count:::==>>> 82 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\AURAIYA2020_to2023_10_26.xlsx
# Surat
# updated file count:::==>>> 83 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Surat2020_to2023_10_26.xlsx
# Sunkesula Barrage
# updated file count:::==>>> 84 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sunkesula Barrage2020_to2023_10_26.xlsx
# Deongaon Bridge
# updated file count:::==>>> 85 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Deongaon Bridge2020_to2023_10_26.xlsx
# Pench Reservoir (Machagora Dam)
# file not updated or not found
# Gandhighat
# updated file count:::==>>> 86 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Gandhighat2020_to2023_10_26.xlsx
# Rangpo Dam
# updated file count:::==>>> 87 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Rangpo Dam2020_to2023_10_26.xlsx
# Birdghat
# updated file count:::==>>> 88 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Birdghat 2020_to2023_10_26.xlsx
# Bareilly
# updated file count:::==>>> 89 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Bareilly2020_to2023_10_26.xlsx
# Srinagar
# updated file count:::==>>> 90 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Srinagar2020_to2023_10_26.xlsx
# Avanigadda
# file not updated or not found
# Narayanpuram Anicut
# file not updated or not found
# Manjlegaon
# updated file count:::==>>> 91 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Manjlegaon2020_to2023_10_26.xlsx
# Somasila Dam
# updated file count:::==>>> 92 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Somasila Dam2020_to2023_10_26.xlsx
# KOSI BARRAGE
# file not updated or not found
# Tilpara  Mihirlal Barrage
# updated file count:::==>>> 93 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Tilpara  Mihirlal Barrage2020_to2023_10_26.xlsx
# Rewaghat
# updated file count:::==>>> 94 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Rewaghat2020_to2023_10_26.xlsx
# Sripada Yellampalli Project
# updated file count:::==>>> 95 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sripada Yellampalli Project2020_to2023_10_26.xlsx
# Padampur
# updated file count:::==>>> 96 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Padampur2020_to2023_10_26.xlsx
# Sonamura
# updated file count:::==>>> 97 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sonamura2020_to2023_10_26.xlsx
# Sangam
# updated file count:::==>>> 98 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sangam2020_to2023_10_26.xlsx
# JINJIRAM
# file not updated or not found
# Hoshangabad
# updated file count:::==>>> 99 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Hoshangabad2020_to2023_10_26.xlsx
# Upper Tunga Prject
# updated file count:::==>>> 100 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Upper Tunga Prject2020_to2023_10_26.xlsx
# P.D. Jurala
# updated file count:::==>>> 101 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\P.D. Jurala2020_to2023_10_26.xlsx
# Munger
# updated file count:::==>>> 102 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Munger2020_to2023_10_26.xlsx
# Gandhi Sagar Reservoir
# file not updated or not found
# Dibrugarh
# updated file count:::==>>> 103 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Dibrugarh2020_to2023_10_26.xlsx
# Gunupur
# updated file count:::==>>> 104 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Gunupur2020_to2023_10_26.xlsx
# Rengali Reservoir
# file not updated or not found
# Jaikwadi Dam
# updated file count:::==>>> 105 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Jaikwadi Dam2020_to2023_10_26.xlsx
# Warna Dam
# updated file count:::==>>> 106 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Warna Dam2020_to2023_10_26.xlsx
# Farakka(FF)
# file not updated or not found
# Sikatia Barrage
# updated file count:::==>>> 107 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sikatia Barrage2020_to2023_10_26.xlsx
# Indrapuri
# updated file count:::==>>> 108 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Indrapuri2020_to2023_10_26.xlsx
# Bharuch
# updated file count:::==>>> 109 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Bharuch2020_to2023_10_26.xlsx
# Mathanguri
# updated file count:::==>>> 110 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Mathanguri2020_to2023_10_26.xlsx
# KODAGANAR DAM
# updated file count:::==>>> 111 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\KODAGANAR DAM2020_to2023_10_26.xlsx
# Badlapur
# updated file count:::==>>> 112 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Badlapur2020_to2023_10_26.xlsx
# Beki Road bridge
# updated file count:::==>>> 113 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Beki Road bridge2020_to2023_10_26.xlsx
# Lucknow (Hanuman Setu)
# updated file count:::==>>> 114 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Lucknow (Hanuman Setu)2020_to2023_10_26.xlsx
# Kopergaon
# updated file count:::==>>> 115 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kopergaon2020_to2023_10_26.xlsx
# Bawanthadi Reservoir
# file not updated or not found
# MOHANA
# updated file count:::==>>> 116 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\MOHANA2020_to2023_10_26.xlsx
# Nanglamoraghat
# updated file count:::==>>> 117 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Nanglamoraghat2020_to2023_10_26.xlsx
# Marshaghai
# updated file count:::==>>> 118 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Marshaghai 2020_to2023_10_26.xlsx
# Kakardhari
# updated file count:::==>>> 119 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kakardhari2020_to2023_10_26.xlsx
# Khadda
# updated file count:::==>>> 120 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Khadda2020_to2023_10_26.xlsx
# Borwa
# updated file count:::==>>> 121 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Borwa2020_to2023_10_26.xlsx
# Dheng Bridge
# updated file count:::==>>> 122 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Dheng Bridge2020_to2023_10_26.xlsx
# Tezpur
# updated file count:::==>>> 123 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Tezpur2020_to2023_10_26.xlsx
# Sripalpur
# updated file count:::==>>> 124 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sripalpur2020_to2023_10_26.xlsx
# Ghazipur
# updated file count:::==>>> 125 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Ghazipur2020_to2023_10_26.xlsx
# Amanat Barrage
# file not updated or not found
# Gosikhurd Dam
# updated file count:::==>>> 126 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Gosikhurd Dam2020_to2023_10_26.xlsx
# Sonbarsa
# updated file count:::==>>> 127 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sonbarsa2020_to2023_10_26.xlsx
# Lalbegiaghat
# updated file count:::==>>> 128 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Lalbegiaghat2020_to2023_10_26.xlsx
# Grand Anicut
# updated file count:::==>>> 129 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Grand Anicut2020_to2023_10_26.xlsx
# SAHIJINA
# updated file count:::==>>> 130 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\SAHIJINA2020_to2023_10_26.xlsx
# Kanas (S)
# file not updated or not found
# Gomukhi Dam
# updated file count:::==>>> 131 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Gomukhi Dam2020_to2023_10_26.xlsx
# Jhawa
# updated file count:::==>>> 132 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Jhawa2020_to2023_10_26.xlsx
# Darauli
# updated file count:::==>>> 133 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Darauli2020_to2023_10_26.xlsx
# Wanakbori Weir
# updated file count:::==>>> 134 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Wanakbori Weir2020_to2023_10_26.xlsx
# Sangampally (Chintavagu)
# updated file count:::==>>> 135 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sangampally (Chintavagu)2020_to2023_10_26.xlsx
# NANDRE
# updated file count:::==>>> 136 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\NANDRE2020_to2023_10_26.xlsx
# Hajipur
# updated file count:::==>>> 137 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Hajipur2020_to2023_10_26.xlsx
# ITCHAPURAM
# file not updated or not found
# Mangaon
# updated file count:::==>>> 138 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Mangaon2020_to2023_10_26.xlsx
# Malaprabha Dam
# updated file count:::==>>> 139 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Malaprabha Dam2020_to2023_10_26.xlsx
# Warunji
# updated file count:::==>>> 140 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Warunji2020_to2023_10_26.xlsx
# Melli
# updated file count:::==>>> 141 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Melli2020_to2023_10_26.xlsx
# DEDTALAI
# updated file count:::==>>> 142 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\DEDTALAI2020_to2023_10_26.xlsx
# Maigalganj
# updated file count:::==>>> 143 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Maigalganj2020_to2023_10_26.xlsx
# Wellington Reservoir
# updated file count:::==>>> 144 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Wellington Reservoir2020_to2023_10_26.xlsx
# Basua
# updated file count:::==>>> 145 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Basua2020_to2023_10_26.xlsx
# Annapurnaghat
# file not updated or not found
# Matijuri
# file not updated or not found
# Pauni
# updated file count:::==>>> 146 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Pauni2020_to2023_10_26.xlsx
# Pipalkoti
# updated file count:::==>>> 147 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Pipalkoti2020_to2023_10_26.xlsx
# Ghugumari
# updated file count:::==>>> 148 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Ghugumari2020_to2023_10_26.xlsx
# SAVANDAPUR
# updated file count:::==>>> 149 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\SAVANDAPUR2020_to2023_10_26.xlsx
# NAINI
# updated file count:::==>>> 150 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\NAINI2020_to2023_10_26.xlsx
# Bhatpura
# updated file count:::==>>> 151 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Bhatpura2020_to2023_10_26.xlsx
# Tufanganj
# updated file count:::==>>> 152 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Tufanganj2020_to2023_10_26.xlsx
# Samastipur
# updated file count:::==>>> 153 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Samastipur2020_to2023_10_26.xlsx
# KODUMUDI
# updated file count:::==>>> 154 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\KODUMUDI2020_to2023_10_26.xlsx
# Rothak
# updated file count:::==>>> 155 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Rothak2020_to2023_10_26.xlsx
# Teesta -V Dam
# file not updated or not found
# Rae bareli
# updated file count:::==>>> 156 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Rae bareli2020_to2023_10_26.xlsx
# RAVISHANKAR SAGAR DAM
# file not updated or not found
# DAHIGAON
# updated file count:::==>>> 157 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\DAHIGAON2020_to2023_10_26.xlsx
# TIGHARA
# updated file count:::==>>> 158 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\TIGHARA2020_to2023_10_26.xlsx
# Pupunki
# updated file count:::==>>> 159 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Pupunki2020_to2023_10_26.xlsx
# KULSI
# updated file count:::==>>> 160 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\KULSI2020_to2023_10_26.xlsx
# Bhadrachalam
# updated file count:::==>>> 161 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Bhadrachalam2020_to2023_10_26.xlsx
# Takli
# updated file count:::==>>> 162 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Takli2020_to2023_10_26.xlsx
# Balimela dam (Sileru)
# updated file count:::==>>> 163 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Balimela dam (Sileru)2020_to2023_10_26.xlsx
# Bargi Reservoir
# updated file count:::==>>> 164 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Bargi Reservoir2020_to2023_10_26.xlsx
# THOTTATHINKADAVU
# updated file count:::==>>> 165 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\THOTTATHINKADAVU2020_to2023_10_26.xlsx
# Dhansa
# file not updated or not found
# MAIGHAT
# updated file count:::==>>> 166 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\MAIGHAT2020_to2023_10_26.xlsx
# Poondi Satyamoorthy Reservoir
# updated file count:::==>>> 167 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Poondi Satyamoorthy Reservoir2020_to2023_10_26.xlsx
# Fatehgarh
# updated file count:::==>>> 168 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Fatehgarh2020_to2023_10_26.xlsx
# KHOLWAD(KATHORE)
# updated file count:::==>>> 169 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\KHOLWAD(KATHORE)2020_to2023_10_26.xlsx
# Sadalga (Seasonal)
# updated file count:::==>>> 170 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sadalga (Seasonal)2020_to2023_10_26.xlsx
# GodavariRlyBridge(Rajahmundry)
# updated file count:::==>>> 171 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\GodavariRlyBridge(Rajahmundry)2020_to2023_10_26.xlsx
# Dighaghat
# updated file count:::==>>> 172 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Dighaghat2020_to2023_10_26.xlsx
# Thoubal_WLR
# file not updated or not found
# MADIKHERA(ATAL SAGAR) DAM
# file not updated or not found
# Ballia
# updated file count:::==>>> 173 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Ballia2020_to2023_10_26.xlsx
# Dharchula
# file not updated or not found
# Rongli Dam
# updated file count:::==>>> 174 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Rongli Dam2020_to2023_10_26.xlsx
# Jalalpur
# updated file count:::==>>> 175 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Jalalpur2020_to2023_10_26.xlsx
# Balrampur
# updated file count:::==>>> 176 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Balrampur2020_to2023_10_26.xlsx
# KALPI
# updated file count:::==>>> 177 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\KALPI2020_to2023_10_26.xlsx
# Pubansa (S)
# file not updated or not found
# Singtam
# updated file count:::==>>> 178 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Singtam2020_to2023_10_26.xlsx
# Indira Sagar Reservoir
# updated file count:::==>>> 179 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Indira Sagar Reservoir2020_to2023_10_26.xlsx
# Dudhnoi
# updated file count:::==>>> 180 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Dudhnoi2020_to2023_10_26.xlsx
# Monierkhal
# updated file count:::==>>> 181 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Monierkhal2020_to2023_10_26.xlsx
# Dharamnagari Barrage
# updated file count:::==>>> 182 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Dharamnagari Barrage2020_to2023_10_26.xlsx
# MALAKKARA
# updated file count:::==>>> 183 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\MALAKKARA2020_to2023_10_26.xlsx
# CHILLAGHAT
# updated file count:::==>>> 184 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\CHILLAGHAT2020_to2023_10_26.xlsx
# Arjunwad (Seasonal)
# updated file count:::==>>> 185 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Arjunwad (Seasonal)2020_to2023_10_26.xlsx
# DHARCHULA
# updated file count:::==>>> 186 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\DHARCHULA2020_to2023_10_26.xlsx
# Bhavani Sagar Dam
# updated file count:::==>>> 187 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Bhavani Sagar Dam 2020_to2023_10_26.xlsx
# Anandpur
# updated file count:::==>>> 188 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Anandpur2020_to2023_10_26.xlsx
# Mayambadi
# updated file count:::==>>> 189 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Mayambadi2020_to2023_10_26.xlsx
# Chatia
# updated file count:::==>>> 190 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Chatia2020_to2023_10_26.xlsx
# Jaldhaka NH-31
# updated file count:::==>>> 191 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Jaldhaka NH-312020_to2023_10_26.xlsx
# Mahi Bajaj Sagar Dam
# updated file count:::==>>> 192 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Mahi Bajaj Sagar Dam2020_to2023_10_26.xlsx
# Buxar
# updated file count:::==>>> 193 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Buxar2020_to2023_10_26.xlsx
# Jaunpur
# updated file count:::==>>> 194 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Jaunpur2020_to2023_10_26.xlsx
# Dantiwada Dam
# updated file count:::==>>> 195 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Dantiwada Dam2020_to2023_10_26.xlsx
# Annaraj Dam
# file not updated or not found
# AKOLA
# updated file count:::==>>> 196 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\AKOLA2020_to2023_10_26.xlsx
# Sriram Sagar Reservoir
# updated file count:::==>>> 197 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sriram Sagar Reservoir2020_to2023_10_26.xlsx
# Muradpur
# updated file count:::==>>> 198 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Muradpur2020_to2023_10_26.xlsx
# Subhash Bridge
# updated file count:::==>>> 199 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Subhash Bridge2020_to2023_10_26.xlsx
# Pancheshwar
# updated file count:::==>>> 200 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Pancheshwar2020_to2023_10_26.xlsx
# Benibad
# updated file count:::==>>> 201 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Benibad2020_to2023_10_26.xlsx
# Parwati Pick- up weir
# file not updated or not found
# Bhadra Reservoir
# updated file count:::==>>> 202 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Bhadra Reservoir2020_to2023_10_26.xlsx
# Pagladiya N T Road Crossing
# updated file count:::==>>> 203 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Pagladiya N T Road Crossing2020_to2023_10_26.xlsx
# Kangsabati Reservoir
# updated file count:::==>>> 204 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kangsabati Reservoir2020_to2023_10_26.xlsx
# UPPER ANICUT
# updated file count:::==>>> 205 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\UPPER ANICUT2020_to2023_10_26.xlsx
# Badarpurghat
# file not updated or not found
# KUMBIDI
# updated file count:::==>>> 206 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\KUMBIDI2020_to2023_10_26.xlsx
# Baltara
# updated file count:::==>>> 207 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Baltara2020_to2023_10_26.xlsx
# Kota City
# updated file count:::==>>> 208 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kota City2020_to2023_10_26.xlsx
# Idamalayar Reservoir
# file not updated or not found
# RUPAS NAGAR
# updated file count:::==>>> 209 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\RUPAS NAGAR2020_to2023_10_26.xlsx
# Atreyapuram (Gauthami)
# updated file count:::==>>> 210 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Atreyapuram (Gauthami)2020_to2023_10_26.xlsx
# Karimganj
# updated file count:::==>>> 211 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Karimganj2020_to2023_10_26.xlsx
# Thong Nambonbi_WLR
# file not updated or not found
# Matatila Reservoir
# updated file count:::==>>> 212 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Matatila Reservoir2020_to2023_10_26.xlsx
# Chhasara
# updated file count:::==>>> 213 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Chhasara2020_to2023_10_26.xlsx
# NAUTGHAT
# updated file count:::==>>> 214 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\NAUTGHAT2020_to2023_10_26.xlsx
# DAMAN
# updated file count:::==>>> 215 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\DAMAN2020_to2023_10_26.xlsx
# Omkareshwar (NHPC) Reservoir
# file not updated or not found
# Kokangaon
# updated file count:::==>>> 216 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kokangaon2020_to2023_10_26.xlsx
# Gangpur Siswan
# updated file count:::==>>> 217 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Gangpur Siswan2020_to2023_10_26.xlsx
# Narsingpur
# updated file count:::==>>> 218 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Narsingpur2020_to2023_10_26.xlsx
# Amarpura
# updated file count:::==>>> 219 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Amarpura2020_to2023_10_26.xlsx
# Hathidah
# updated file count:::==>>> 220 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Hathidah2020_to2023_10_26.xlsx
# Rammunshibagh (near Srinagar)
# updated file count:::==>>> 221 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Rammunshibagh (near Srinagar)2020_to2023_10_26.xlsx
# Rishikesh
# updated file count:::==>>> 222 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Rishikesh2020_to2023_10_26.xlsx
# NAUKUCHIATAL
# file not updated or not found
# Bansagar Dam
# updated file count:::==>>> 223 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Bansagar Dam2020_to2023_10_26.xlsx
# Indo-Nepal Border (Bhutahi)
# updated file count:::==>>> 224 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Indo-Nepal Border (Bhutahi)2020_to2023_10_26.xlsx
# Therriaghat
# file not updated or not found
# Varanasi
# updated file count:::==>>> 225 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Varanasi2020_to2023_10_26.xlsx
# PANBARI
# updated file count:::==>>> 226 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\PANBARI2020_to2023_10_26.xlsx
# DHOLPUR
# updated file count:::==>>> 227 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\DHOLPUR2020_to2023_10_26.xlsx
# Allahabad
# updated file count:::==>>> 228 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Allahabad2020_to2023_10_26.xlsx
# Harangi Reservoir
# updated file count:::==>>> 229 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Harangi Reservoir2020_to2023_10_26.xlsx
# Alandurai
# updated file count:::==>>> 230 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Alandurai2020_to2023_10_26.xlsx
# Kolar Reservoir
# updated file count:::==>>> 231 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kolar Reservoir2020_to2023_10_26.xlsx
# Gangakhed W/L Station
# file not updated or not found
# Hinglow Dam
# file not updated or not found
# Vaigai Reservoir
# updated file count:::==>>> 232 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Vaigai Reservoir2020_to2023_10_26.xlsx
# HATHNUR
# updated file count:::==>>> 233 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\HATHNUR2020_to2023_10_26.xlsx
# Kannauj
# updated file count:::==>>> 234 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kannauj2020_to2023_10_26.xlsx
# HARUR
# updated file count:::==>>> 235 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\HARUR2020_to2023_10_26.xlsx
# Sairang
# updated file count:::==>>> 236 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sairang2020_to2023_10_26.xlsx
# PACHAWALI
# updated file count:::==>>> 237 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\PACHAWALI2020_to2023_10_26.xlsx
# Gadarwara
# updated file count:::==>>> 238 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Gadarwara2020_to2023_10_26.xlsx
# Hidkal Reservoir
# updated file count:::==>>> 239 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Hidkal Reservoir2020_to2023_10_26.xlsx
# Kahalgaon
# updated file count:::==>>> 240 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kahalgaon2020_to2023_10_26.xlsx
# Fateh Garh
# updated file count:::==>>> 241 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Fateh Garh2020_to2023_10_26.xlsx
# Hasimara
# updated file count:::==>>> 242 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Hasimara2020_to2023_10_26.xlsx
# Alipingal
# updated file count:::==>>> 243 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Alipingal2020_to2023_10_26.xlsx
# Palwa
# updated file count:::==>>> 244 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Palwa2020_to2023_10_26.xlsx
# MADHUBAN DAM
# updated file count:::==>>> 245 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\MADHUBAN DAM2020_to2023_10_26.xlsx
# SONAPUR
# file not updated or not found
# KAILASHAHAR GDSQ SITE
# updated file count:::==>>> 246 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\KAILASHAHAR GDSQ SITE2020_to2023_10_26.xlsx
# Yinkiang
# updated file count:::==>>> 247 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Yinkiang2020_to2023_10_26.xlsx
# PANGKHUAH
# file not updated or not found
# BANDA
# updated file count:::==>>> 248 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\BANDA2020_to2023_10_26.xlsx
# Salandi Reservoir
# file not updated or not found
# Sardar Sarovar Project_Gujarat Reservoir
# updated file count:::==>>> 249 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sardar Sarovar Project_Gujarat Reservoir2020_to2023_10_26.xlsx
# Karad
# updated file count:::==>>> 250 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Karad2020_to2023_10_26.xlsx
# Purwamir
# updated file count:::==>>> 251 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Purwamir2020_to2023_10_26.xlsx
# GAJARIA
# updated file count:::==>>> 252 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\GAJARIA2020_to2023_10_26.xlsx
# Garudeshwar
# updated file count:::==>>> 253 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Garudeshwar2020_to2023_10_26.xlsx
# Minuthong_WLR
# file not updated or not found
# Koyna
# updated file count:::==>>> 254 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Koyna2020_to2023_10_26.xlsx
# Dowlaiswaram (State Govt Site)
# updated file count:::==>>> 255 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Dowlaiswaram (State Govt Site)2020_to2023_10_26.xlsx
# Suyalbari
# updated file count:::==>>> 256 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Suyalbari2020_to2023_10_26.xlsx
# Nasik
# ...
# Sitalpur
# file not updated or not found
# Dalsingh Sarai
# file not updated or not found
# Jagibhakatgaon
# updated file count:::==>>> 1168 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Jagibhakatgaon2020_to2023_10_26.xlsx
# Dhanora (Kathani)
# updated file count:::==>>> 1169 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Dhanora (Kathani)2020_to2023_10_26.xlsx
# Fatehpur
# updated file count:::==>>> 1170 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Fatehpur2020_to2023_10_26.xlsx
# KOCHUPAMPA
# file not updated or not found
# CHICHURA
# updated file count:::==>>> 1171 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\CHICHURA2020_to2023_10_26.xlsx
# Rangeli
# updated file count:::==>>> 1172 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Rangeli2020_to2023_10_26.xlsx
# Brahmkhaal
# updated file count:::==>>> 1173 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Brahmkhaal2020_to2023_10_26.xlsx
# PALASIPARA
# file not updated or not found
# Narasingarayainpet
# updated file count:::==>>> 1174 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Narasingarayainpet2020_to2023_10_26.xlsx
# Purad
# updated file count:::==>>> 1175 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Purad2020_to2023_10_26.xlsx
# Seorinarayan
# updated file count:::==>>> 1176 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Seorinarayan2020_to2023_10_26.xlsx
# Byrnihat
# file not updated or not found
# Tumri
# file not updated or not found
# Ahiro
# file not updated or not found
# Tumnar (Dantewara)
# updated file count:::==>>> 1177 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Tumnar (Dantewara)2020_to2023_10_26.xlsx
# Rauta
# file not updated or not found
# Bolani
# updated file count:::==>>> 1178 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Bolani2020_to2023_10_26.xlsx
# Badarpur Ghat
# updated file count:::==>>> 1179 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Badarpur Ghat2020_to2023_10_26.xlsx
# Rajghat
# file not updated or not found
# AMBITTAMPOTTY
# file not updated or not found
# Zamania
# file not updated or not found
# Surajgarh
# updated file count:::==>>> 1180 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Surajgarh2020_to2023_10_26.xlsx
# Halon at Baratola
# updated file count:::==>>> 1181 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Halon at Baratola2020_to2023_10_26.xlsx
# Manpur
# file not updated or not found
# AYALAMBEDU
# updated file count:::==>>> 1182 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\AYALAMBEDU2020_to2023_10_26.xlsx
# BEDEPARA
# updated file count:::==>>> 1183 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\BEDEPARA2020_to2023_10_26.xlsx
# Regauli
# updated file count:::==>>> 1184 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Regauli2020_to2023_10_26.xlsx
# Kutragada
# updated file count:::==>>> 1185 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kutragada2020_to2023_10_26.xlsx
# Chintawanpur
# updated file count:::==>>> 1186 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Chintawanpur2020_to2023_10_26.xlsx
# BANGAON
# updated file count:::==>>> 1187 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\BANGAON2020_to2023_10_26.xlsx
# Belsand
# updated file count:::==>>> 1188 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Belsand2020_to2023_10_26.xlsx
# Saidpur
# updated file count:::==>>> 1189 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Saidpur2020_to2023_10_26.xlsx
# Andhiyar Khore
# updated file count:::==>>> 1190 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Andhiyar Khore2020_to2023_10_26.xlsx
# KUTTYADI
# updated file count:::==>>> 1191 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\KUTTYADI2020_to2023_10_26.xlsx
# Pathardihi
# updated file count:::==>>> 1192 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Pathardihi2020_to2023_10_26.xlsx
# Sankara
# updated file count:::==>>> 1193 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sankara2020_to2023_10_26.xlsx
# GHISH
# updated file count:::==>>> 1194 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\GHISH2020_to2023_10_26.xlsx
# Dhamaraghat
# file not updated or not found
# Khab
# updated file count:::==>>> 1195 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Khab2020_to2023_10_26.xlsx
# Sikti
# file not updated or not found
# Swaroopganj
# updated file count:::==>>> 1196 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Swaroopganj2020_to2023_10_26.xlsx
# Kakarghatti
# updated file count:::==>>> 1197 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kakarghatti2020_to2023_10_26.xlsx
# Bachhwara
# file not updated or not found
# Puduvayal
# updated file count:::==>>> 1198 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Puduvayal2020_to2023_10_26.xlsx
# Shella
# file not updated or not found
# Villupuram
# updated file count:::==>>> 1199 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Villupuram2020_to2023_10_26.xlsx
# Mungapar
# updated file count:::==>>> 1200 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Mungapar2020_to2023_10_26.xlsx
# BERHAIT
# updated file count:::==>>> 1201 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\BERHAIT2020_to2023_10_26.xlsx
# Thengudi
# updated file count:::==>>> 1202 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Thengudi2020_to2023_10_26.xlsx
# FARAKKA(HR)
# updated file count:::==>>> 1203 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\FARAKKA(HR)2020_to2023_10_26.xlsx
# JANNAPURA
# updated file count:::==>>> 1204 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\JANNAPURA2020_to2023_10_26.xlsx
# Dhareri
# updated file count:::==>>> 1205 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Dhareri2020_to2023_10_26.xlsx
# Sankhili Rd Bridge
# file not updated or not found
# BAROT
# updated file count:::==>>> 1206 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\BAROT2020_to2023_10_26.xlsx
# HANSKHALI
# updated file count:::==>>> 1207 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\HANSKHALI2020_to2023_10_26.xlsx
# RAMPUR
# file not updated or not found
# Keonjhar
# updated file count:::==>>> 1208 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Keonjhar2020_to2023_10_26.xlsx
# KALNA (flow)
# updated file count:::==>>> 1209 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\KALNA (flow)2020_to2023_10_26.xlsx
# Singavaram
# updated file count:::==>>> 1210 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Singavaram2020_to2023_10_26.xlsx
# CHIKKARASINAKERE
# updated file count:::==>>> 1211 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\CHIKKARASINAKERE2020_to2023_10_26.xlsx
# Markhandadeo
# file not updated or not found
# Vazhavachanur
# updated file count:::==>>> 1212 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Vazhavachanur2020_to2023_10_26.xlsx
# Kumarapalayam
# updated file count:::==>>> 1213 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kumarapalayam2020_to2023_10_26.xlsx
# ADDOOR
# updated file count:::==>>> 1214 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\ADDOOR2020_to2023_10_26.xlsx
# MUDIGERE
# file not updated or not found
# Nandadih1
# updated file count:::==>>> 1215 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Nandadih12020_to2023_10_26.xlsx
# Haralahalli
# updated file count:::==>>> 1216 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Haralahalli2020_to2023_10_26.xlsx
# Kateela
# updated file count:::==>>> 1217 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Kateela2020_to2023_10_26.xlsx
# Anthara
# updated file count:::==>>> 1218 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Anthara2020_to2023_10_26.xlsx
# KELLODU
# updated file count:::==>>> 1219 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\KELLODU2020_to2023_10_26.xlsx
# VYTHIRI
# file not updated or not found
# KOPPA
# file not updated or not found
# Sangla
# updated file count:::==>>> 1220 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sangla2020_to2023_10_26.xlsx
# SRINGERI
# file not updated or not found
# VALIGONDA
# updated file count:::==>>> 1221 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\VALIGONDA2020_to2023_10_26.xlsx
# Sandi
# updated file count:::==>>> 1222 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sandi2020_to2023_10_26.xlsx
# Paliakalan
# updated file count:::==>>> 1223 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Paliakalan2020_to2023_10_26.xlsx
# SOMWARPET
# file not updated or not found
# Maneri
# updated file count:::==>>> 1224 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Maneri2020_to2023_10_26.xlsx
# Bagaha
# file not updated or not found
# GULLING
# updated file count:::==>>> 1225 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\GULLING2020_to2023_10_26.xlsx
# Yuksum
# updated file count:::==>>> 1226 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Yuksum2020_to2023_10_26.xlsx
# Anantharam
# updated file count:::==>>> 1227 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Anantharam2020_to2023_10_26.xlsx
# Borkhandi
# updated file count:::==>>> 1228 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Borkhandi2020_to2023_10_26.xlsx
# Sultanpur
# updated file count:::==>>> 1229 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sultanpur2020_to2023_10_26.xlsx
# HANSA
# updated file count:::==>>> 1230 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\HANSA2020_to2023_10_26.xlsx
# Todarpur
# updated file count:::==>>> 1231 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Todarpur2020_to2023_10_26.xlsx
# Ranikor
# file not updated or not found
# HARIHARAPURA
# updated file count:::==>>> 1232 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\HARIHARAPURA2020_to2023_10_26.xlsx
# TIRTHAHALLI
# file not updated or not found
# MUKKODLU
# updated file count:::==>>> 1233 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\MUKKODLU2020_to2023_10_26.xlsx
# FATEHGANJ (E)
# updated file count:::==>>> 1234 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\FATEHGANJ (E)2020_to2023_10_26.xlsx
# NARASIMHARAJAPURA
# file not updated or not found
# Thandalaiputhur
# updated file count:::==>>> 1235 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Thandalaiputhur2020_to2023_10_26.xlsx
# Bangpura
# updated file count:::==>>> 1236 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Bangpura2020_to2023_10_26.xlsx
# MADIKERI
# file not updated or not found
# MANANTHAVADY
# file not updated or not found
# KUPPELUR
# updated file count:::==>>> 1237 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\KUPPELUR2020_to2023_10_26.xlsx
# T.K.HALLI
# updated file count:::==>>> 1238 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\T.K.HALLI2020_to2023_10_26.xlsx
# BISWANATHPUR
# updated file count:::==>>> 1239 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\BISWANATHPUR2020_to2023_10_26.xlsx
# HADIGE
# file not updated or not found
# Gokak Falls
# updated file count:::==>>> 1240 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Gokak Falls2020_to2023_10_26.xlsx
# Fica Barrage
# updated file count:::==>>> 1241 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Fica Barrage2020_to2023_10_26.xlsx
# Mohgaon
# updated file count:::==>>> 1242 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Mohgaon2020_to2023_10_26.xlsx
# SEMARKHEDI
# updated file count:::==>>> 1243 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\SEMARKHEDI2020_to2023_10_26.xlsx
# HATTIHOLE
# file not updated or not found
# SAKLESHPUR
# updated file count:::==>>> 1244 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\SAKLESHPUR2020_to2023_10_26.xlsx
# BALEHONNUR
# file not updated or not found
# Honnali
# updated file count:::==>>> 1245 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Honnali2020_to2023_10_26.xlsx
# MUTHANKERA
# updated file count:::==>>> 1246 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\MUTHANKERA2020_to2023_10_26.xlsx
# Sirimoda
# updated file count:::==>>> 1247 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Sirimoda2020_to2023_10_26.xlsx
# MAHISHI
# updated file count:::==>>> 1248 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\MAHISHI2020_to2023_10_26.xlsx
# MADAPURA
# file not updated or not found
# Peralam
# updated file count:::==>>> 1249 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Peralam2020_to2023_10_26.xlsx
# Magaral
# updated file count:::==>>> 1250 <<< updated path >>>>>F:\phd_work\cwc_real_time_data\updated_real_time\data_files\2020_updated\data\Magaral2020_to2023_10_26.xlsx
